# %% [markdown]
# TABLE DES MATIERES
#
# 1. Introduction
# 2. Traitement des données
# 3. Analyse exploratoire
# 4. Analyse de qualité
# 5. Analyse patrimoniale
# 6. Synthèse
# 7. Conclusion
# 8. Bibilographie
